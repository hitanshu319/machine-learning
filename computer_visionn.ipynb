# %% [markdown]
# <a href="https://colab.research.google.com/github/hitanshu319/machine-learning/blob/master/computer_visionn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

import matplotlib.pyplot as plt

from google.colab.patches import cv2_imshow

# %%
print(cv2.__version__)
# Out:
# 3.4.3

# %%
img=cv2.imread("dog.jpg")

img
# Out:
# array([[[  8,  62,  57],
#         [  8,  62,  57],
#         [  8,  62,  57],
#         ...,
#         [ 79, 147, 140],
#         [ 79, 147, 140],
#         [ 79, 147, 140]],
#
#        [[  6,  60,  55],
#         [  6,  60,  55],
#         [  6,  60,  55],
#         ...,
#         [ 79, 147, 140],
#         [ 79, 147, 140],
#         [ 79, 147, 140]],
#
#        [[  6,  58,  51],
#         [  6,  58,  51],
#         [  6,  57,  53],
#         ...,
#         [ 79, 147, 140],
#         [ 79, 147, 140],
#         [ 79, 147, 140]],
#
#        ...,
#
#        [[ 12,  62,  58],
#         [ 11,  61,  57],
#         [ 12,  59,  56],
#         ...,
#         [176, 204, 234],
#         [172, 200, 230],
#         [168, 196, 227]],
#
#        [[ 13,  63,  59],
#         [ 11,  61,  57],
#         [ 12,  59,  56],
#         ...,
#         [175, 203, 233],
#         [173, 201, 231],
#         [170, 198, 229]],
#
#        [[ 13,  63,  59],
#         [ 12,  62,  58],
#         [ 13,  60,  57],
# ...

# %%
#shape of image

img.shape
# Out:
# (340, 453, 3)

# %%
#type of image

type(img)
# Out:
# numpy.ndarray

# %%
#t display image

plt.imshow(img)

# %%
#wait for windws to close

cv2.waitkey(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-23509187c8a1> in <module>()
#       1
# ----> 2 cv2.waitkey(0)
#
# AttributeError: module 'cv2.cv2' has no attribute 'waitkey'

# %%
img1=cv2.imread("dog.jpg",1) #for black n white
img2=cv2.imread("dog.jpg",0)  #for coloured

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
cv2.im
